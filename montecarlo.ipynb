# %%
import random
import math
mean = 30
sigma = 0.05
time = 25

# %%
for j in range(0,200) :
    for i in range(time):
        x = random.normalvariate(0, sigma)
        y_normal = mean + x
        print(y_normal, ' ')
# Out:
# 30.03886547196592
# 30.00950028456356
# 30.063993754928354
# 29.98643216823329
# 29.998988912274093
# 29.924742790597023
# 29.968134675170596
# 30.037640125545316
# 30.001453796834355
# 30.06045812852959
# 30.00607936753123
# 30.062680230738025
# 30.062662117293893
# 30.00416816034698
# 29.91494384426538
# 29.94622928962345
# 29.967182882921627
# 30.032312555283365
# 29.96119012553119
# 30.045158872464448
# 29.877804171046773
# 29.972863995215132
# 29.97500884100694
# 30.028159651670872
# 30.014531013861344
# 30.0730266741286
# 29.999712260001566
# 29.998967703113625
# 29.897161624929574
# 29.869126491270563
# 30.03958482555258
# 30.10024782679458
# 29.946486656218188
# 30.019454765457958
# 29.959302934641755
# 29.993879619384636
# 29.93105142325254
# 29.97769858860882
# 29.980904252198325
# 29.99046796929874
# 29.969957459045137
# 29.942888566988625
# 30.063331309226864
# 30.08410186421626
# 30.00188541138725
# 29.998051389798228
# 29.980378300024473
# 30.07000069726443
# ...
